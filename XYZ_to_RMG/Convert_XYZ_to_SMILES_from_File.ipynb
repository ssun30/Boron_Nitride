# %%
from rdmc.mol import Mol
from rdtools.view import mol_viewer
from rdkit.Chem.Draw import IPythonConsole
from rdtools.fix import fix_mol, saturate_mol, remedy_manager

import os

# %%
# Set file path

fpath = os.path.join(os.getcwd(), 'Vuori', 'xyz_coordinates.txt')

# %%
# Read xyz coordinates from file

xyz_list = []

with open(fpath, 'r') as file:
    xyz = ""
    for line in file:
        line = line.strip()
        if line:
            xyz += line +"\n"
        elif xyz:
            xyz_list.append(xyz.strip())
            xyz = ""

    if xyz:
        xyz_list.append(xyz.strip())

# %%
# Write smiles to file

output_path = os.path.join(os.getcwd(), 'Vuori', 'smiles.txt')

with open (output_path, 'w') as file:
    for xyz in xyz_list:
        # Get the molecule name
        mol_name = xyz.split("\n")[1].split()[0]
        mol_name = mol_name.replace("-", "\n", 1)

        # Skip diborane-like structures with "Banana Bonds" for now
        if mol_name.startswith('4'):
            continue

        try:
            # Try to get molecule from xyz using 'xyz2mol' backend
            mol = Mol.FromXYZ(xyz, backend='xyz2mol', header=True)
            print(f"Using xyz2mol to process molecular xyz coordinates for {mol_name}")
        except Exception:
            print(f"xyz2mol backend failed for {mol_name}. Trying openbabel backend.")
            try:
                # If 'xyz2mol' fails, try 'openbabel' backend
                mol = Mol.FromXYZ(xyz, backend='openbabel', header=True)
                print(f"Using openbabel to process molecular xyz coordinates for {mol_name}")
            except Exception as e:
                # Print the xyz coordinates that caused the exception
                print(f"Error processing xyz: {xyz}\nException: {e}")
                continue

        try:
            # Get SMILES for the molecule
            smiles = mol.ToSmiles()

            output_string = f"{mol_name}\n{smiles}\n\n"
            file.write(output_string)
        except Exception as e:
            # Print the xyz coordinates that caused the exception
            print(f"Error converting to SMILES: {xyz}\nException: {e}")
# Out:
# Using xyz2mol to process molecular xyz coordinates for 1a
# BH3
# Using xyz2mol to process molecular xyz coordinates for 1b
# BH2Me
# Using xyz2mol to process molecular xyz coordinates for 1c
# BH2Et
# Using xyz2mol to process molecular xyz coordinates for 1d
# BH2Vi
# Using xyz2mol to process molecular xyz coordinates for 1e
# BH2Pr
# Using xyz2mol to process molecular xyz coordinates for 1f
# BH2iPr
# Using xyz2mol to process molecular xyz coordinates for 1g
# BH2sBu
# Using xyz2mol to process molecular xyz coordinates for 1h
# BH2tBu
# Using xyz2mol to process molecular xyz coordinates for 1i
# BH2Ph
# Using xyz2mol to process molecular xyz coordinates for 2a
# BHMe2
# Using xyz2mol to process molecular xyz coordinates for 2b
# BHEtMe
# Using xyz2mol to process molecular xyz coordinates for 2c
# BHMeVi
# Using xyz2mol to process molecular xyz coordinates for 2d
# BHMePh
# Using xyz2mol to process molecular xyz coordinates for 2e
# BHEt2
# Using xyz2mol to process molecular xyz coordinates for 2f
# BHEtVi
# Using xyz2mol to process molecular xyz coordinates for 2g
# BHVi2
# Using xyz2mol to process molecular xyz coordinates for 2h
# BHPhVi
# Using xyz2mol to process molecular xyz coordinates for 2i
# BHiPr2
# Using xyz2mol to process molecular xyz coordinates for 2j
# BHPh2
# Using xyz2mol to process molecular xyz coordinates for 3a
# BMe3
# Using xyz2mol to process molecular xyz coordinates for 3b
# BEtMe2
# Using xyz2mol to process molecular xyz coordinates for 3c
# BMe2Vi
# Using xyz2mol to process molecular xyz coordinates for 3d
# BMe2Ph
# Using xyz2mol to process molecular xyz coordinates for 3e
# BEtMePh
# Using xyz2mol to process molecular xyz coordinates for 3f
# BMeVi2
# Using xyz2mol to process molecular xyz coordinates for 3g
# BMePhVi
# Using xyz2mol to process molecular xyz coordinates for 3h
# BMePh2
# Using xyz2mol to process molecular xyz coordinates for 3i
# BF2Me
# Using xyz2mol to process molecular xyz coordinates for 3j
# BEt3
# Using xyz2mol to process molecular xyz coordinates for 3k
# BEtVi2
# Using xyz2mol to process molecular xyz coordinates for 3l
# BEtF2
# Using xyz2mol to process molecular xyz coordinates for 3m
# BVi3
# Using xyz2mol to process molecular xyz coordinates for 3n
# BPhVi2
# Using xyz2mol to process molecular xyz coordinates for 3o
# BPh2Vi
# Using xyz2mol to process molecular xyz coordinates for 3p
# BF2Vi
# Using xyz2mol to process molecular xyz coordinates for 3q
# BiPr3
# Using xyz2mol to process molecular xyz coordinates for 3r
# BBu3
# Using xyz2mol to process molecular xyz coordinates for 3s
# BPh3
# Using xyz2mol to process molecular xyz coordinates for 3t
# BF3
# Using xyz2mol to process molecular xyz coordinates for 3u
# BCl3
# Using xyz2mol to process molecular xyz coordinates for 5a
# BH2(OH)
# Using xyz2mol to process molecular xyz coordinates for 5b
# BH2(OMe)
# Using xyz2mol to process molecular xyz coordinates for 5c
# BH2(OEt)
# Using xyz2mol to process molecular xyz coordinates for 5d
# BH2(OPh)
# Using xyz2mol to process molecular xyz coordinates for 5e
# BHMe(OH)
# Using xyz2mol to process molecular xyz coordinates for 5f
# BHEt(OH)
# Using xyz2mol to process molecular xyz coordinates for 5g
# BHPh(OH)
# Using xyz2mol to process molecular xyz coordinates for 5h
# BHMe(OMe)
# Using xyz2mol to process molecular xyz coordinates for 5i
# BHEt(OMe)
# Using xyz2mol to process molecular xyz coordinates for 5j
# BHPh(OMe)
# Using xyz2mol to process molecular xyz coordinates for 5k
# BMe2(OH)
# Using xyz2mol to process molecular xyz coordinates for 5l
# BMe2(OMe)
# Using xyz2mol to process molecular xyz coordinates for 5m
# BEtMe(OH)
# Using xyz2mol to process molecular xyz coordinates for 5n
# BMePh(OH)
# Using xyz2mol to process molecular xyz coordinates for 5o
# BMePh(OMe)
# Using xyz2mol to process molecular xyz coordinates for 6a
# BH(OH)2
# Using xyz2mol to process molecular xyz coordinates for 6b
# BH(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 6c
# BH(iPrO)2
# Using xyz2mol to process molecular xyz coordinates for 6d
# BMe(OH)2
# Using xyz2mol to process molecular xyz coordinates for 6e
# BMe(OH)(OMe)
# Using xyz2mol to process molecular xyz coordinates for 6f
# BMe(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 6g
# BMe(OEt)(OMe)
# Using xyz2mol to process molecular xyz coordinates for 6h
# BMe(OEt)2
# Using xyz2mol to process molecular xyz coordinates for 6i
# BEt(OH)2
# Using xyz2mol to process molecular xyz coordinates for 6j
# BEt(OH)(OMe)
# Using xyz2mol to process molecular xyz coordinates for 6k
# BEt(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 6l
# BVi(OH)2
# Using xyz2mol to process molecular xyz coordinates for 6m
# BVi(OH)(OMe)
# Using xyz2mol to process molecular xyz coordinates for 6n
# BVi(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 6o
# B(All)(OH)2
# Using xyz2mol to process molecular xyz coordinates for 6p
# B(All)(OH)(OMe)
# Using xyz2mol to process molecular xyz coordinates for 6q
# B(All)(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 6r
# BPh(OH)2
# Using xyz2mol to process molecular xyz coordinates for 6s
# BPh(OH)(OMe)
# Using xyz2mol to process molecular xyz coordinates for 6t
# BPh(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 6u
# B(p-Tol)(OH)2
# Using xyz2mol to process molecular xyz coordinates for 6v
# B(p-Tol)(OH)(OMe)
# Using xyz2mol to process molecular xyz coordinates for 6w
# B(p-Tol)(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 7a
# B(OH)3
# Using xyz2mol to process molecular xyz coordinates for 7b
# B(OH)2(OMe)
# Using xyz2mol to process molecular xyz coordinates for 7c
# B(OH)2(OPh)
# Using xyz2mol to process molecular xyz coordinates for 7d
# B(OH)(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 7e
# B(OH)(OMe)(OPh)
# Using xyz2mol to process molecular xyz coordinates for 7f
# B(OMe)3
# Using xyz2mol to process molecular xyz coordinates for 7g
# B(OEt)(OMe)2
# Using xyz2mol to process molecular xyz coordinates for 7h
# B(OMe)2(OPh)
# Using xyz2mol to process molecular xyz coordinates for 7i
# B(OEt)2(OMe)
# Using xyz2mol to process molecular xyz coordinates for 7j
# B(OMe)(OPh)2
# Using xyz2mol to process molecular xyz coordinates for 7k
# B(OEt)3
# Using xyz2mol to process molecular xyz coordinates for 8a
# C6H4O2B
# Using xyz2mol to process molecular xyz coordinates for 8b
# C6H4O2BMe
# Using xyz2mol to process molecular xyz coordinates for 8c
# 3-C6H3FO2BMe
# Using xyz2mol to process molecular xyz coordinates for 8d
# 4-C6H3FO2BMe
# Using xyz2mol to process molecular xyz coordinates for 8e
# 3,4-C6H2F2O2BMe
# xyz2mol backend failed for 8f
# 3,5-C6H2F2O2BMe. Trying openbabel backend.
# Error processing xyz: 17
# 8f-3,5-C6H2F2O2BMe symmetry C1
# C     -0.987673   -1.503184   -0.002103
# C      0.220056   -0.835115   -0.005182
# C      0.322688    0.550522   -0.003981
# C     -0.818147    1.325681    0.000182
# C     -2.059448    0.700012    0.003956
# C     -2.111788   -0.686511    0.002707
# H     -1.067898   -2.578759   -0.003170
# O      1.485625   -1.364648   -0.011834
# O      1.645178    0.917385   -0.010118
# B      2.361889   -0.276886   -0.011008
# C      3.910618   -0.385992    0.012665
# H      4.383489    0.487074   -0.436116
# H      4.266628   -0.449729    1.045102
# H      4.259382   -1.282413   -0.499937
# F     -0.739958    2.662736    0.000819
# H     -2.966348    1.285030    0.007984
# Exception: Unable to parse the provided xyz.
# Using xyz2mol to process molecular xyz coordinates for 8g
# 3,6-C6H2F2O2BMe
# Using xyz2mol to process molecular xyz coordinates for 8h
# 4,5-C6H2F2O2BMe
# Using xyz2mol to process molecular xyz coordinates for 8i
# 3,4,5-C6HF3O2BMe
# Using xyz2mol to process molecular xyz coordinates for 8j
# 3,4,6-C6HF3O2BMe
# Using xyz2mol to process molecular xyz coordinates for 8k
# C6F4O2BMe
# Using xyz2mol to process molecular xyz coordinates for 9a
# BH2NH2
# Using xyz2mol to process molecular xyz coordinates for 9b
# BH2NHMe
# Using xyz2mol to process molecular xyz coordinates for 9c
# BH2NMe2
# Using xyz2mol to process molecular xyz coordinates for 9d
# BHMeNH2
# Using xyz2mol to process molecular xyz coordinates for 9e
# BMe2NH2
# Using xyz2mol to process molecular xyz coordinates for 10
# BH(NMe2)2
# Using xyz2mol to process molecular xyz coordinates for 11
# B(NMe2)3
# Using xyz2mol to process molecular xyz coordinates for 12
# B(SMe)3
# Using xyz2mol to process molecular xyz coordinates for 13
# B3H6N3
# ==============================
# *** Open Babel Warning  in ReadMolecule
#   Problems reading an XYZ file: Could not read line #19, file error.
#  According to line one, there should be 17 atoms, and therefore 19 lines in the file.
