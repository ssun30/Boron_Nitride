# %%
import os
import re
import glob

import rmgpy.chemkin
import rmgpy.data.kinetics
import rmgpy.data.thermo

import numpy as np
# import importlib
# importlib.reload(rmgpy.data.kinetics)

import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict

from arkane.main import Arkane
import os
import logging
# Out:
# WARNING: method definition for getreactionindices at /home/ssun30/ReactionMechanismSimulator.jl/src/Phase.jl:320 declares type variable Q but does not use it.
# WARNING: method definition for Inlet at /home/ssun30/ReactionMechanismSimulator.jl/src/Interface.jl:243 declares type variable B but does not use it.
# WARNING: method definition for #ConstantTPDomain#328 at /home/ssun30/ReactionMechanismSimulator.jl/src/Domain.jl:42 declares type variable W but does not use it.
# WARNING: method definition for #ConstantTPDomain#328 at /home/ssun30/ReactionMechanismSimulator.jl/src/Domain.jl:42 declares type variable Q but does not use it.
# WARNING: method definition for #ConstantTPDomain#328 at /home/ssun30/ReactionMechanismSimulator.jl/src/Domain.jl:42 declares type variable E but does not use it.
# WARNING: method definition for #ConstantVDomain#339 at /home/ssun30/ReactionMechanismSimulator.jl/src/Domain.jl:120 declares type variable Q but does not use it.
# ...

# %%
# load the ts arkane
working_dir = 'BH3'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Thu Jun 13 21:16:34 2024
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	f037ba9b40cdde3b59f1597ec96bc8ff745de35e
# 	Thu Jun 13 19:45:55 2024 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'BCl3'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Thu Jun 13 21:16:39 2024
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	f037ba9b40cdde3b59f1597ec96bc8ff745de35e
# 	Thu Jun 13 19:45:55 2024 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'Borazine'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 06:47:07 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'Cl3BNH3'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 06:48:13 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'Cl2BNH2'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 06:49:04 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'ClBNH'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 06:50:47 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'ClB(NH2)2'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 06:56:51 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'B(NH2)3'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 06:58:20 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'NH3'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 06:59:58 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'HCl'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 07:00:39 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
# load the ts arkane
working_dir = 'Cl3BNH3-Cl2BNH2-rxn'

arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = True
arkane_ts.execute()
# Out:
# Arkane execution initiated at Tue Dec 12 08:30:17 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.2.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	afdb59778c08360d5676f636abe6893c86733b0a
# 	Mon Oct 9 19:17:25 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
basedir = "/home/harris.se/bill_green_kinetics/rxn1"
thermo_libs = glob.glob(os.path.join(basedir, '*', 'arkane_m062x*', 'RMG_libraries'))
print(f'{len(thermo_libs)} thermo libs')


# Load the Arkane thermo
entries = []
for i, lib_path in enumerate(thermo_libs):
    ark_thermo_database = rmgpy.data.thermo.ThermoDatabase()
    ark_thermo_database.load_libraries(
        lib_path,
    )

    for key in ark_thermo_database.libraries['thermo'].entries.keys():
        entry = ark_thermo_database.libraries['thermo'].entries[key]
#         entry.index = species_index
        entry.label = entry.item.smiles
        entries.append(entry)
print(f'{len(entries)} entries')
print(entries)
# Out:
# ERROR:root:Error while reading database '/home/harris.se/bill_green_kinetics/rxn1/ts/arkane_m062x/RMG_libraries/reactions.py'.
# 4 thermo libs
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_44906/3147669374.py in <module>
#       9     ark_thermo_database = rmgpy.data.thermo.ThermoDatabase()
#      10     ark_thermo_database.load_libraries(
# ---> 11         lib_path,
#      12     )
#      13
#
# ~/rmg/RMG-Py/rmgpy/data/thermo.py in load_libraries(self, path, libraries)
#     934                         logging.info('Loading thermodynamics library from {0} in {1}...'.format(f, root))
#     935                         library = ThermoLibrary()
# --> 936                         library.load(os.path.join(root, f), self.local_context, self.global_context)
#     937                         library.label = os.path.splitext(f)[0]
# ...

# %%
T = 1000
delta_G = entries[2].data.get_free_energy(T) - (entries[0].data.get_free_energy(T) + entries[1].data.get_free_energy(T))
print(delta_G)  # kJ / mol

K = np.exp(-delta_G / rmgpy.constants.R / T)
print("{:e}".format(K))
# Out:
# 12045.372122715547
# 2.348699e-01

# %%
dG_300 = 3.034 - (-2.090 + 21.673)
dG_1000 = -59.810 - (-46.048 + -16.641)

# %%
entries[1].data
# Out:
# NASA(polynomials=[NASAPolynomial(coeffs=[3.98129,0.00111466,9.42091e-06,-1.42699e-08,7.45732e-12,16675.1,0.223766], Tmin=(10,'K'), Tmax=(473.028,'K')), NASAPolynomial(coeffs=[3.61123,0.00424402,-5.02665e-07,-2.83793e-10,6.53627e-14,16710.2,1.73206], Tmin=(473.028,'K'), Tmax=(3000,'K'))], Tmin=(10,'K'), Tmax=(3000,'K'), E0=(138.636,'kJ/mol'), Cp0=(33.2579,'J/(mol*K)'), CpInf=(83.1447,'J/(mol*K)'))

# %%
# Out:
# WARNING:root:Optional package dependency "xlwt" not loaded. Some output features will not work.

# %%
working_dir = '/home/harris.se/bill_green_kinetics/rxn1/ch3/jupiter_arkane'
os.chdir(working_dir)


arkane = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane.plot = False
arkane.execute()
# Out:
# Arkane execution initiated at Wed Sep 27 20:50:20 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.1.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	d8f1ba1b6d67c130ff5d7340fb351df2c93170e1
# 	Mon Jul 17 10:59:50 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
import rmgpy

# %%
arkane.output_directory
# Out:
# '/home/harris.se/bill_green_kinetics/rxn1/ch3/jupiter_arkane'

# %%
arkane.transition_state_dict
# Out:
# {}

# %%
T = 1000
arkane.job_list[1].species.conformer.modes[0].get_partition_function(T)
# Out:
# 47154592.13530543

# %%
T = 1000
print(arkane.job_list[0].species.conformer.modes[0])
q_trans  = arkane.job_list[0].species.conformer.modes[0].get_partition_function(T)
print('{:e}'.format(q_trans))
# Out:
# IdealGasTranslation(mass=(15.0235,'amu'))
# 4.715459e+07

# %%
rmgpy.constants.Na
# Out:
# 6.02214179e+23

# %%
m = arkane.job_list[0].species.conformer.modes[0].mass.value_si
T = 1000.0

# do this on a per mol basis: N = Nav

P = 101325
V = rmgpy.constants.Na * rmgpy.constants.kB * T / P
q_trans = np.float_power(2.0 * np.pi * m * rmgpy.constants.kB * T / np.float_power(rmgpy.constants.h, 2.0), 1.5)

print('{:e}'.format(q_trans))
# Out:
# 3.460644e+32

# %% [markdown]
# # Translation Partition Function

# %%
T = 1000
print(arkane.job_list[0].species.conformer.modes[0])
q_trans  = arkane.job_list[0].species.conformer.modes[0].get_partition_function(T)
print('{:e}'.format(q_trans))


m = arkane.job_list[0].species.conformer.modes[0].mass.value_si
T = 1000.0
P = 101325
V = rmgpy.constants.Na * rmgpy.constants.R * T / P

q_trans = np.float_power(2.0 * np.pi * m * rmgpy.constants.kB * T / np.float_power(rmgpy.constants.h, 2.0), 1.5) *  \
    rmgpy.constants.kB * T / P





print('{:e}'.format(q_trans))
# Out:
# IdealGasTranslation(mass=(15.0235,'amu'))
# 4.715459e+07
# 4.715459e+07

# %% [markdown]
# # Rotation Partition Function

# %%
T = 1000
print(arkane.job_list[0].species.conformer.modes[1])
print('{:e}'.format(arkane.job_list[0].species.conformer.modes[1].get_partition_function(T)))
print()


theta = np.float_power(rmgpy.constants.h, 2.0) / (8.0 * np.pi * np.pi * rmgpy.constants.kB * \
                                                  arkane.job_list[0].species.conformer.modes[1].inertia.value_si)

q_rot = np.sqrt(np.pi) / arkane.job_list[0].species.conformer.modes[1].symmetry * \
    np.sqrt(np.float_power(T, 3.0) / theta[0] / theta[1] / theta[2])

print('{:e}'.format(q_rot))
print()
# Out:
# NonlinearRotor(inertia=([1.75167,1.75167,3.50333],'amu*angstrom^2'), symmetry=6)
# 2.564080e+02
#
# 2.564081e+02

# %% [markdown]
# # Vibrational partition function

# %%
T = 1000
print(arkane.job_list[0].species.conformer.modes[2])
print('{:e}'.format(arkane.job_list[0].species.conformer.modes[2].get_partition_function(T)))
print()


# arkane.job_list[0].species.conformer.modes[2].quantum

theta = arkane.job_list[0].species.conformer.modes[2].frequencies.value * 100.0 * rmgpy.constants.c * rmgpy.constants.h / rmgpy.constants.kB
print(f'theta {[np.round(t, 2) for t in theta]}')

# components = [np.exp(-t / (2.0 * T)) / (1.0 - np.exp(-t / T)) for t in theta]
components = [np.exp(-t / (2.0 * T)) / (1.0 - np.exp(-t / T)) for t in theta]

components = [1.0 / (1.0 - np.exp(-t / T)) for t in theta]

# zpe = 0.5 * np.sum(rmgpy.constants.h * (arkane.job_list[0].species.conformer.modes[2].frequencies.value * 100.0 * rmgpy.constants.c))
# print(f'ZPE {zpe}')

# e_elec = arkane.job_list[0].species.conformer.E0.value_si / rmgpy.constants.Na
# print(f'e_elec {e_elec}')

# print(np.exp(-(e_elec + ZPE) / ( rmgpy.constants.kB * T)))

print(np.product(np.array(components)))

# %%
arkane.job_list[0].species.conformer.E0

# %%
print(np.exp(-ZPE / ( rmgpy.constants.kB * T)))

# %% [markdown]
# # total partition function

# %%
T=1000
q_total = arkane.job_list[0].species.conformer.get_partition_function(T)

print('{:e}'.format(q_total))
print()


q_trans = arkane.job_list[0].species.conformer.modes[0].get_partition_function(T)
q_rot = arkane.job_list[0].species.conformer.modes[1].get_partition_function(T)
q_vib = arkane.job_list[0].species.conformer.modes[2].get_partition_function(T)
q_elec = 2.0
q_total = q_trans * q_rot * q_vib * q_elec

print('{:e}'.format(q_total))
print()

# %%
working_dir = '/home/harris.se/bill_green_kinetics/rxn1/ch2ch2/arkane_m062x'
os.chdir(working_dir)


arkane = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane.plot = False
arkane.execute()

# %%
T=300
q_total = arkane.job_list[0].species.conformer.get_partition_function(T)

print('T=300 {:e}'.format(q_total))
print()

T=1000
q_total = arkane.job_list[0].species.conformer.get_partition_function(T)

print('T=1000 {:e}'.format(q_total))
print()

# %%
working_dir = '/home/harris.se/bill_green_kinetics/rxn1/ch3ch2ch2/arkane_m062x'
os.chdir(working_dir)


arkane = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.INFO)
arkane.plot = False
arkane.execute()

# %%
T=300
q_total = arkane.job_list[0].species.conformer.get_partition_function(T)

print('T=300 {:e}'.format(q_total))
print()

T=1000
q_total = arkane.job_list[0].species.conformer.get_partition_function(T)

print('T=1000 {:e}'.format(q_total))
print()

# %% [markdown]
# # helmholtz

# %%
T = 1000
print(arkane.job_list[0].species.conformer.modes[2])
print('{:e}'.format(arkane.job_list[0].species.conformer.modes[2].get_partition_function(T)))
print()


# arkane.job_list[0].species.conformer.modes[2].quantum

theta = arkane.job_list[0].species.conformer.modes[2].frequencies.value * 100.0 * rmgpy.constants.c * rmgpy.constants.h / rmgpy.constants.kB
print(f'theta {[np.round(t, 2) for t in theta]}')

# components = [np.exp(-t / (2.0 * T)) / (1.0 - np.exp(-t / T)) for t in theta]
components = [np.exp(-t / (2.0 * T)) / (1.0 - np.exp(-t / T)) for t in theta]

components = [1.0 / (1.0 - np.exp(-t / T)) for t in theta]

# zpe = 0.5 * np.sum(rmgpy.constants.h * (arkane.job_list[0].species.conformer.modes[2].frequencies.value * 100.0 * rmgpy.constants.c))
# print(f'ZPE {zpe}')

# e_elec = arkane.job_list[0].species.conformer.E0.value_si / rmgpy.constants.Na
# print(f'e_elec {e_elec}')

# print(np.exp(-(e_elec + ZPE) / ( rmgpy.constants.kB * T)))

print(np.product(np.array(components)))

# %%
for working_dir in [
    '/home/harris.se/bill_green_kinetics/rxn1/ch3/arkane_m062x',
    '/home/harris.se/bill_green_kinetics/rxn1/ch2ch2/arkane_m062x',
    '/home/harris.se/bill_green_kinetics/rxn1/ch3ch2ch2/arkane_m062x'
]:
    os.chdir(working_dir)

    arkane = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.INFO)
    arkane.plot = False
    arkane.execute()
    
    
    print(working_dir)
    T = 300
    print(np.round(arkane.job_list[0].species.thermo.get_free_energy(T) / 1000.0, 3))
    
    T = 1000
    print(np.round(arkane.job_list[0].species.thermo.get_free_energy(T) / 1000.0, 3))

# %%
working_dir = '/home/harris.se/bill_green_kinetics/rxn1/ch3/arkane_m062x'
os.chdir(working_dir)


arkane = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane.plot = False
arkane.execute()
# Out:
# Arkane execution initiated at Wed Sep 27 20:51:56 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.1.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	d8f1ba1b6d67c130ff5d7340fb351df2c93170e1
# 	Mon Jul 17 10:59:50 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
T = 1000
print(arkane.job_list[0].species.thermo.get_free_energy(T))

P = 101325

q = arkane.job_list[0].species.conformer.get_partition_function(T)

N = 1.0

V = rmgpy.constants.kB * T / P
mu = -rmgpy.constants.kB * T * (np.log(q * V)) 



# print(mu * Na)


N = rmgpy.constants.Na
N = 1
A = -N * rmgpy.constants.kB * T * np.log(q * np.exp(1) / N) #Na * rmgpy.constants.kB * T
G = A - N * rmgpy.constants.kB * T

# print(A)
print(G * rmgpy.constants.Na)

# print(-rmgpy.constants.kB * T * np.log(q) * Na)
# Out:
# -69625.4606619812
#         Calculating Partition Function for IdealGasTranslation
#         Calculating Partition Function for NonlinearRotor
#         Calculating Partition Function for HarmonicOscillator
# -224920.32974425706

# %%
# Rxn1 300
12.692 - (90.678 + -8.746)
# Out:
# -69.24000000000001

# %%
# Rxn1 1000
-250.246 - (-192.666 + -69.625)
# Out:
# 12.044999999999987

# %%
# import the actual reaction library...

import os
import re
import glob

import rmgpy.chemkin
import rmgpy.data.kinetics
import rmgpy.data.thermo

import numpy as np
# import importlib
# importlib.reload(rmgpy.data.kinetics)

import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict

# %%
DFT_DIR = "/home/harris.se/bill_green_kinetics/rxn1/"
thermo_libs = glob.glob(os.path.join(DFT_DIR, '*', 'arkane_m062x', 'RMG_libraries'))
print(f'{len(thermo_libs)} thermo libs')


# Load the Arkane thermo
entries = []
for i, lib_path in enumerate(thermo_libs):
    if '/ts/' in lib_path:
        continue
    species_index = i
    ark_thermo_database = rmgpy.data.thermo.ThermoDatabase()
    ark_thermo_database.load_libraries(
        lib_path,
    )

    for key in ark_thermo_database.libraries['thermo'].entries.keys():
        entry = ark_thermo_database.libraries['thermo'].entries[key]
        entry.index = species_index
        entry.label = entry.item.smiles
        entries.append(entry)
print(f'{len(entries)} entries')
# Out:
# 4 thermo libs
# Loading thermodynamics library from thermo.py in /home/harris.se/bill_green_kinetics/rxn1/ch2ch2/arkane_m062x/RMG_libraries...
# Loading thermodynamics library from thermo.py in /home/harris.se/bill_green_kinetics/rxn1/ch3/arkane_m062x/RMG_libraries...
# Loading thermodynamics library from thermo.py in /home/harris.se/bill_green_kinetics/rxn1/ch3ch2ch2/arkane_m062x/RMG_libraries...
# 3 entries

# %%
entries

# %%
# first, get valid kinetics from old workflow
rxn_dir = '/home/harris.se/bill_green_kinetics/rxn1/ts/arkane_m062x'
kinetics_lib = os.path.join(rxn_dir, 'RMG_libraries')


ark_kinetics_database = rmgpy.data.kinetics.KineticsDatabase()
ark_kinetics_database.load_libraries(kinetics_lib)
# Out:
# Loading kinetics library  from /home/harris.se/bill_green_kinetics/rxn1/ts/arkane_m062x/RMG_libraries/reactions.py...

# %%
ark_kinetics_database.libraries[''].entries[0].item.reactants[0].thermo = entries[1].data

# %%
ark_kinetics_database.libraries[''].entries[0].item.reactants[1].thermo = entries[0].data

# %%
ark_kinetics_database.libraries[''].entries[0].item.products[0].thermo = entries[2].data

# %%
T = 1000
ark_kinetics_database.libraries[''].entries[0].item.get_free_energy_of_reaction(T)
# Out:
# 12045.372122715547

# %%
T = 300
ark_kinetics_database.libraries[''].entries[0].item.get_free_energy_of_reaction(T)
# Out:
# -69239.67200039531

# %%
T = 1000
print(f'T={T}')
print('{:e}'.format(ark_kinetics_database.libraries[''].entries[0].item.get_equilibrium_constant(T)))
print()

dG = ark_kinetics_database.libraries[''].entries[0].item.get_free_energy_of_reaction(T)
print(f'dG = {dG}')
print(np.exp(-dG / rmgpy.constants.R / T))
# Out:
# T=1000
# 1.952819e-02
#
# dG = 12045.372122715547
# 0.23486987587954158

# %%
T = 1000
q_ch3 = 7.582286e+10
q_ch2ch2 = 3.120273e+12
q_ch3ch2ch2 = 3.754507e+17
P0 = 101325
# dG = -rmgpy.constants.R * T * np.log(q_ch3ch2ch2 / q_ch3 / q_ch2ch2)
# dG = -rmgpy.constants.R * T * np.log(q_ch3ch2ch2 * P0 / q_ch3 / q_ch2ch2 / (rmgpy.constants.R * T))

dG = -rmgpy.constants.R * T * np.log(q_ch3ch2ch2 / q_ch3 / q_ch2ch2 * (rmgpy.constants.R * T) / P0) * rmgpy.constants.R * T / P0



print(f'dG = {dG}')
print(np.exp(-dG / rmgpy.constants.R / T))


print(np.exp(-dG / rmgpy.constants.R / T) * rmgpy.constants.R * T)
# Out:
# dG = 7404.867172892012
# 0.4104095117029151
# 3412.3383935875604

# %%
q_ch3ch2ch2 / q_ch3 / q_ch2ch2  * P0 / (rmgpy.constants.kB * T) / rmgpy.constants.Na
# Out:
# 1.9339359036033996e-05

# %%
rmgpy.constants.R * 1000 / 101325
# Out:
# 0.08205745867258821

# %%
ark_kinetics_database.libraries[''].entries[0].data.get_rate_coefficient(300)
# Out:
# 0.6237587427436633

# %%
T = 1000
K_eq = ark_kinetics_database.libraries[''].entries[0].item.get_equilibrium_constant(T)
k_fwd = ark_kinetics_database.libraries[''].entries[0].data.get_rate_coefficient(T)

k_rev = k_fwd / K_eq
print(k_rev)
# Out:
# 1567931.9516110136

# %%
# load the ts arkane
working_dir = '/home/harris.se/bill_green_kinetics/rxn1/ts/arkane_m062x'
os.chdir(working_dir)


arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = False
arkane_ts.execute()
# Out:
# Arkane execution initiated at Wed Sep 27 20:51:41 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.1.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	d8f1ba1b6d67c130ff5d7340fb351df2c93170e1
# 	Mon Jul 17 10:59:50 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
for mode in arkane_ts.job_list[-2].species.conformer.modes:
    print(mode)
# Out:
# IdealGasTranslation(mass=(43.0548,'amu'))
# NonlinearRotor(inertia=([17.9783,77.611,85.3685],'amu*angstrom^2'), symmetry=1)
# HarmonicOscillator(frequencies=([113.477,220.555,350.885,498.678,521.345,784.009,785.417,855.497,931.444,991.276,1186.81,1253.66,1361.89,1366.44,1401.63,1522.49,2974.76,3016.64,3026.52,3090.2,3116.81,3126.19,3136.74],'cm^-1'))

# %%
T = 300
# arkane_ts.job_list[-2].species.conformer.get_partition_function(T)

q_ts = arkane_ts.job_list[-2].species.conformer.get_partition_function(T)

print('{:e}'.format(q_ts))
# Out:
#         Calculating Partition Function for IdealGasTranslation
#         Calculating Partition Function for NonlinearRotor
#         Calculating Partition Function for HarmonicOscillator
# 3.545970e+12

# %%
arkane_ts.job_list[-2].species
# Out:
# TransitionState(label="TS", conformer=Conformer(E0=(219.52,'kJ/mol'), modes=[IdealGasTranslation(mass=(43.0548,'amu')), NonlinearRotor(inertia=([17.9783,77.611,85.3685],'amu*angstrom^2'), symmetry=1), HarmonicOscillator(frequencies=([113.477,220.555,350.885,498.678,521.345,784.009,785.417,855.497,931.444,991.276,1186.81,1253.66,1361.89,1366.44,1401.63,1522.49,2974.76,3016.64,3026.52,3090.2,3116.81,3126.19,3136.74],'cm^-1'))], spin_multiplicity=2), frequency=(-567.022,'cm^-1'))

# %%
T = 300
q_ch3 = arkane_ts.job_list[0].species.get_partition_function(T)
q_ch2ch2 = arkane_ts.job_list[2].species.get_partition_function(T)
q_ts = arkane_ts.job_list[-2].species.get_partition_function(T)
# Out:
#         Calculating Partition Function for IdealGasTranslation
#         Calculating Partition Function for NonlinearRotor
#         Calculating Partition Function for HarmonicOscillator
#         Calculating Partition Function for IdealGasTranslation
#         Calculating Partition Function for NonlinearRotor
#         Calculating Partition Function for HarmonicOscillator
#         Calculating Partition Function for IdealGasTranslation
#         Calculating Partition Function for NonlinearRotor
#         Calculating Partition Function for HarmonicOscillator

# %%
arkane_ts.job_list[0].species
# Out:
# Error: Cairo not found; molecule will not be drawn.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /work/westgroup/harris.se/tst_env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/rmg/RMG-Py/rmgpy/species.cpython-37m-x86_64-linux-gnu.so in rmgpy.species.Species._repr_png_()
#
# ~/rmg/RMG-Py/rmgpy/molecule/molecule.cpython-37m-x86_64-linux-gnu.so in rmgpy.molecule.molecule.Molecule._repr_png_()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp_molecule.png'
# ...

# %%
delta_E0 = arkane_ts.job_list[-2].species.conformer.E0.value_si - (
    arkane_ts.job_list[0].species.conformer.E0.value_si + arkane_ts.job_list[2].species.conformer.E0.value_si
)
P = 101325
k_tst = q_ts / q_ch3 / q_ch2ch2 * np.exp(-delta_E0 / (rmgpy.constants.R * T)) * rmgpy.constants.kB * T / rmgpy.constants.h
k_tst = k_tst * rmgpy.constants.R * T / P
# print('{:e}'.format(k_tst))
print(k_tst)
# Out:
# 0.6043340404501389

# %%
rmgpy.constants.kB * T
# Out:
# 1.3806504e-20

# %%
arkane_ts.job_list[-1].reaction.kinetics.get_rate_coefficient(T)
# Out:
# 30619.141767225545

# %%
dir(arkane_ts.job_list[-1])
# Out:
# ['K_eq_units',
#  'Tcount',
#  'Tlist',
#  'Tmax',
#  'Tmin',
#  '_Tlist',
#  '_Tmax',
#  '_Tmin',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'arkane_species',
#  'draw',
#  'execute',
#  'generate_kinetics',
#  'k_r_units',
#  'k_units',
#  'plot',
#  'reaction',
#  'save_yaml',
#  'sensitivity_conditions',
#  'three_params',
#  'usedTST',
#  'write_chemkin',
#  'write_output']

# %%
np.exp()

# %%
delta_E0
# Out:
# 34397.30238280282

# %%
219.52 - (138.676 + 46.4658)
# Out:
# 34.37820000000002

# %%
arkane_ts.job_list[0].species
# Out:
# Error: Cairo not found; molecule will not be drawn.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /work/westgroup/harris.se/tst_env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/rmg/RMG-Py/rmgpy/species.cpython-37m-x86_64-linux-gnu.so in rmgpy.species.Species._repr_png_()
#
# ~/rmg/RMG-Py/rmgpy/molecule/molecule.cpython-37m-x86_64-linux-gnu.so in rmgpy.molecule.molecule.Molecule._repr_png_()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp_molecule.png'
# ...

# %%
100000/(rmgpy.constants.R * 1000) * 0.0195
# Out:
# 0.23453082769416989

# %%
100000/(rmgpy.constants.R * 300) * 2.3e10
# Out:
# 922087014865.9669

# %%
print(arkane_ts.job_list[-2].species.conformer.modes)
# Out:
# [IdealGasTranslation(mass=(43.0548,'amu')), NonlinearRotor(inertia=([17.9783,77.611,85.3685],'amu*angstrom^2'), symmetry=1), HarmonicOscillator(frequencies=([113.477,220.555,350.885,498.678,521.345,784.009,785.417,855.497,931.444,991.276,1186.81,1253.66,1361.89,1366.44,1401.63,1522.49,2974.76,3016.64,3026.52,3090.2,3116.81,3126.19,3136.74],'cm^-1'))]

# %%
dir(arkane_ts.job_list[-3])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'arkane_species',
#  'element_count_from_conformer',
#  'execute',
#  'generate_thermo',
#  'plot',
#  'species',
#  'thermo_class',
#  'write_chemkin',
#  'write_output']

# %%
arkane_ts.job_list[-1].reaction
# Out:
# Error: Cairo not found; molecule will not be drawn.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /work/westgroup/harris.se/tst_env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/rmg/RMG-Py/rmgpy/reaction.cpython-37m-x86_64-linux-gnu.so in rmgpy.reaction.Reaction._repr_png_()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp_reaction.png'
# ...

# %%
dir(arkane_ts.job_list[-1])
# Out:
# ['K_eq_units',
#  'Tcount',
#  'Tlist',
#  'Tmax',
#  'Tmin',
#  '_Tlist',
#  '_Tmax',
#  '_Tmin',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'arkane_species',
#  'draw',
#  'execute',
#  'generate_kinetics',
#  'k_r_units',
#  'k_units',
#  'plot',
#  'reaction',
#  'save_yaml',
#  'sensitivity_conditions',
#  'three_params',
#  'usedTST',
#  'write_chemkin',
#  'write_output']

# %%
dir(ark_kinetics_database.libraries[''].entries[0].data)

# %%
829136.980059553 /  250245.7594631732

# %%
dir(arkane.job_list[0].species.thermo)

# %%
theta

# %%
theta[0]

# %%
arkane.job_list[0].species.conformer.modes[1].inertia.value_si

# %%
arkane.job_list[0].species.conformer.modes[1].inertia.value_si

# %%
m

# %%
rmgpy.constants.Na

# %%
rmgpy.constants.kB

# %%
dir(arkane.job_list[0].species.conformer.modes[0])

# %%
dir(arkane)

# %%
import rmgpy.reaction

# %%
Arrhenius(A=(3772.56,'cm^3/(mol*s)'), n=2.7666, Ea=(26.6198,'kJ/mol')

# %%
A = 3772.56
n = 2.7666
T = 300
Ea = 26.6198


R = 8314
k = A * T ** n * np.exp(-Ea / (R * T))

# %%
print('{:e}'.format(k))

# %%
DFT_DIR = "/home/harris.se/bill_green_kinetics/rxn2/"
thermo_libs = glob.glob(os.path.join(DFT_DIR, '*', 'arkane_cc*', 'RMG_libraries'))
print(f'{len(thermo_libs)} thermo libs')


# Load the Arkane thermo
entries = []
for i, lib_path in enumerate(thermo_libs):
    if '/ts/' in lib_path:
        continue
    species_index = i
    ark_thermo_database = rmgpy.data.thermo.ThermoDatabase()
    ark_thermo_database.load_libraries(
        lib_path,
    )

    for key in ark_thermo_database.libraries['thermo'].entries.keys():
        entry = ark_thermo_database.libraries['thermo'].entries[key]
        entry.index = species_index
        entry.label = entry.item.smiles
        entries.append(entry)
print(f'{len(entries)} entries')
# Out:
# 5 thermo libs
# Loading thermodynamics library from thermo.py in /home/harris.se/bill_green_kinetics/rxn2/H2NO/arkane_ccpvtz/RMG_libraries...
# Loading thermodynamics library from thermo.py in /home/harris.se/bill_green_kinetics/rxn2/HONO/arkane_ccpvtz/RMG_libraries...
# Loading thermodynamics library from thermo.py in /home/harris.se/bill_green_kinetics/rxn2/NH2OH/arkane_ccpvtz/RMG_libraries...
# Loading thermodynamics library from thermo.py in /home/harris.se/bill_green_kinetics/rxn2/NO2/arkane_ccpvtz/RMG_libraries...
# 4 entries

# %%
entries


# # order is 
# H2NO
# HONO
# H2NOH
# NO2
# Out:
# [<Entry index=0 label="N[O]">,
#  <Entry index=1 label="[O][N]O">,
#  <Entry index=2 label="NO">,
#  <Entry index=3 label="[O]N=O">]

# %%
# first, get valid kinetics from old workflow
rxn_dir = '/home/harris.se/bill_green_kinetics/rxn2/ts/arkane_ccpvtz'
kinetics_lib = os.path.join(rxn_dir, 'RMG_libraries')


ark_kinetics_database = rmgpy.data.kinetics.KineticsDatabase()
ark_kinetics_database.load_libraries(kinetics_lib)
# Out:
# Loading kinetics library  from /home/harris.se/bill_green_kinetics/rxn2/ts/arkane_ccpvtz/RMG_libraries/reactions.py...

# %%
entries[1].data
# Out:
# NASA(polynomials=[NASAPolynomial(coeffs=[4.05932,-0.00537966,5.69763e-05,-9.96814e-08,5.65657e-11,-107420,6.49802], Tmin=(10,'K'), Tmax=(566.508,'K')), NASAPolynomial(coeffs=[3.12231,0.0099098,-6.47259e-06,2.01101e-09,-2.3762e-13,-107453,9.2577], Tmin=(566.508,'K'), Tmax=(3000,'K'))], Tmin=(10,'K'), Tmax=(3000,'K'), E0=(-893.144,'kJ/mol'), Cp0=(33.2579,'J/(mol*K)'), CpInf=(83.1447,'J/(mol*K)'))

# %%
ark_kinetics_database.libraries[''].entries[0].item.products[0].thermo = entries[1].data
ark_kinetics_database.libraries[''].entries[0].item.products[1].thermo = entries[0].data

# %%
ark_kinetics_database.libraries[''].entries[0].item.reactants[1].thermo = entries[2].data
ark_kinetics_database.libraries[''].entries[0].item.reactants[0].thermo = entries[3].data

# %%
ark_kinetics_database.libraries[''].entries[0].item.get_free_energy_of_reaction(1000)
# Out:
# -20644.546389413998

# %%
T = 300
K_eq = ark_kinetics_database.libraries[''].entries[0].item.get_equilibrium_constant(T)
k_fwd = ark_kinetics_database.libraries[''].entries[0].data.get_rate_coefficient(T)

# %%
K_eq
# Out:
# 138.18125094827695

# %%
k_rev = k_fwd / K_eq

# %%
k_rev
# Out:
# 0.003478846183248714

# %%
ark_kinetics_database.libraries[''].entries[0].item.generate_reverse_rate_coefficient()
# Out:
# ---------------------------------------------------------------------------
# ReactionError                             Traceback (most recent call last)
# /tmp/ipykernel_22112/1399438852.py in <module>
# ----> 1 ark_kinetics_database.libraries[''].entries[0].item.generate_reverse_rate_coefficient(1000)
#
# ~/rmg/RMG-Py/rmgpy/reaction.cpython-37m-x86_64-linux-gnu.so in rmgpy.reaction.Reaction.generate_reverse_rate_coefficient()
#
# ~/rmg/RMG-Py/rmgpy/reaction.cpython-37m-x86_64-linux-gnu.so in rmgpy.reaction.Reaction.generate_reverse_rate_coefficient()
#
# ReactionError: Unexpected kinetics type <class 'NoneType'>; should be one of ('KineticsData', 'Arrhenius', 'SurfaceArrhenius', 'MultiArrhenius', 'PDepArrhenius', 'MultiPDepArrhenius', 'Chebyshev', 'ThirdBody', 'Lindemann', 'Troe', 'StickingCoefficient')

# %%
# load the ts arkane
working_dir = '/home/harris.se/bill_green_kinetics/rxn2/ts/arkane_ccpvtz'
os.chdir(working_dir)


arkane_ts = Arkane(input_file=os.path.join(working_dir, 'input.py'), output_directory=working_dir, verbose=logging.DEBUG)
arkane_ts.plot = False
arkane_ts.execute()
# Out:
# Arkane execution initiated at Wed Sep 27 23:48:40 2023
#
# ################################################################
# #                                                              #
# # Automated Reaction Kinetics and Network Exploration (Arkane) #
# #                                                              #
# #   Version: 3.1.0                                             #
# #   Authors: RMG Developers (rmg_dev@mit.edu)                  #
# #   P.I.s:   William H. Green (whgreen@mit.edu)                #
# #            Richard H. West (r.west@neu.edu)                  #
# #   Website: http://reactionmechanismgenerator.github.io/      #
# #                                                              #
# ################################################################
#
# The current git HEAD for RMG-Py is:
# 	d8f1ba1b6d67c130ff5d7340fb351df2c93170e1
# 	Mon Jul 17 10:59:50 2023 -0400
#
# The current git HEAD for RMG-database is:
# ...

# %%
arkane_ts.job_list[-1].reaction
# Out:
# Error: Cairo not found; molecule will not be drawn.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /work/westgroup/harris.se/tst_env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/rmg/RMG-Py/rmgpy/reaction.cpython-37m-x86_64-linux-gnu.so in rmgpy.reaction.Reaction._repr_png_()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'temp_reaction.png'
# ...

# %%
dir(arkane_ts.job_list[-1])
# Out:
# ['K_eq_units',
#  'Tcount',
#  'Tlist',
#  'Tmax',
#  'Tmin',
#  '_Tlist',
#  '_Tmax',
#  '_Tmin',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'arkane_species',
#  'draw',
#  'execute',
#  'generate_kinetics',
#  'k_r_units',
#  'k_units',
#  'plot',
#  'reaction',
#  'save_yaml',
#  'sensitivity_conditions',
#  'three_params',
#  'usedTST',
#  'write_chemkin',
#  'write_output']

# %%
k_rev = k_fwd / K_eq
